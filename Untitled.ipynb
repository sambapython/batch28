# %%
print 1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-e19d6e6ac7e1> in <module>()
# ----> 1 print 1/0
#
# ZeroDivisionError: integer division or modulo by zero

# %%
print "sdfdsf"
# Out:
# sdfdsf

# %%
a=10
b="dfsfds"
print a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-31ee63a1aaa4> in <module>()
#       1 a=10
#       2 b="dfsfds"
# ----> 3 print a+b
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a=10

# %%
print a
# Out:
# 10

# %%
print a+200
# Out:
# 210

# %%
print a%3
# Out:
# 1

# %%
print "st1"
print "st2"
print "st3"
print "st4"
# Out:
# st1
# st2
# st3
# st4

# %%
print "st1"
a=raw_input("Enter:")
# a==10
print "st2"
print "st3"

print "st4"

# %%
#looping for while
for i in range(10):
    print "st",i
# Out:
# st 0
# st 1
# st 2
# st 3
# st 4
# st 5
# st 6
# st 7
# st 8
# st 9

# %%
print "st1"
print "st2"
print "st3"
print "st4"
# Out:
# st1
# st2
# st3
# st4

# %%
#looping for while
for i in range(1,5):
    print "st"+str(i)
# Out:
# st1
# st2
# st3
# st4

# %%
s="Ashok, Anil, Jagadish, rajesh"

# %%
s[0]
# Out:
# 'A'

# %%
for i in s:
    print i
# Out:
# A
# s
# h
# o
# k
# ,
#
# A
# n
# i
# l
# ,
#
# J
# a
# g
# a
# d
# i
# s
# h
# ,
#
# r
# a
# j
# e
# s
# h

# %%
for i in range(10):
    print "st1",i
# Out:
# st1 0
# st1 1
# st1 2
# st1 3
# st1 4
# st1 5
# st1 6
# st1 7
# st1 8
# st1 9

# %%
print "some starting statements"
a=10
b=20
print "a={0}, b={1}".format(a,b)
print "result=",a+b
a=30
b=40
print "a={0}, b={1}".format(a,b)
print "result=",a+b
a=50
b=60
print "a={0}, b={1}".format(a,b)
print "result=",a+b
a=70 
b=80
print "a={0}, b={1}".format(a,b)
print "result=",a+b
# Out:
# some starting statements
# a=10, b=20
# result= 30
# a=30, b=40
# result= 70
# a=50, b=60
# result= 110
# a=70, b=80
# result= 150

# %%
print "some starting statements"
for a,b in [(10,20),(30,40),(50,60),(70,80)]:
    print "a={0}, b={1}".format(a,b)
    print "result=",a+b
# Out:
# some starting statements
# a=10, b=20
# result= 30
# a=30, b=40
# result= 70
# a=50, b=60
# result= 110
# a=70, b=80
# result= 150

# %%
print "some starting statements"
a=10
b=20
print "a={0}, b={1}".format(a,b)
print "summation=",a+b
print "some more statements"
a=30
b=40
print "a={0}, b={1}".format(a,b)
print "summation=",a+b
print "other statements"
a=50
b=60
print "a={0}, b={1}".format(a,b)
print "summation=",a+b
print "few more statements"
a=70 
b=80
print "a={0}, b={1}".format(a,b)
print "summation=",a+b
# Out:
# some starting statements
# a=10, b=20
# summation= 30
# some more statements
# a=30, b=40
# summation= 70
# other statements
# a=50, b=60
# summation= 110
# few more statements
# a=70, b=80
# summation= 150

# %%
def fun(a,b):
    print "a={0}, b={1}".format(a,b)
    print "summation=",a+b
    
print "some starting statements"
fun(10,20)
print "some more statements"
fun(30,40)
print "other statements"
fun(50,60)
print "few more statements"
fun(70,80)
# Out:
# some starting statements
# a=10, b=20
# summation= 30
# some more statements
# a=30, b=40
# summation= 70
# other statements
# a=50, b=60
# summation= 110
# few more statements
# a=70, b=80
# summation= 150

# %%
# 400 + 20=420
a= raw_input("Enter some value:")

# %%
# 400+ 20+3=423
def fun():
    a=raw_input("Enter some value:")
    return a

# %%
print "program started"
a=raw_input("enter a value:")
b=raw_input("Enter b values:")
a=int(a)
b=int(b)
print a+b
print "few other statements"
print "program ended"
# Out:
# program started
# enter a value:10
# Enter b values:20
# 30
# few other statements
# program ended

# %%
print "program started"
a=raw_input("enter a value:")
b=raw_input("Enter b values:")
a=int(a)
b=int(b)
print a+b
print "few other statements"
print "program ended"
# Out:
# program started
# enter a value:asdfdasf
# Enter b values:sdfs
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-f1a5b2870dac> in <module>()
#       2 a=raw_input("enter a value:")
#       3 b=raw_input("Enter b values:")
# ----> 4 a=int(a)
#       5 b=int(b)
#       6 print a+b
#
# ValueError: invalid literal for int() with base 10: 'asdfdasf'

# %%
pwd
# Out:
# u'/home/tcloudost/pythonexamples/batch27'
